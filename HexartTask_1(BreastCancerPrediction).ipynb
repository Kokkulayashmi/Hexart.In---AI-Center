# %% [markdown]
# <a href="https://colab.research.google.com/github/Kokkulayashmi/Hexart.In---AI-Center/blob/main/HexartTask_1(BreastCancerPrediction).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/breastcancer.zip")

# %%
data
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          334 non-null    object
#  1   Age                 334 non-null    float64
#  2   Gender              334 non-null    object
#  3   Protein1            334 non-null    float64
#  4   Protein2            334 non-null    float64
#  5   Protein3            334 non-null    float64
#  6   Protein4            334 non-null    float64
#  7   Tumour_Stage        334 non-null    object
#  8   Histology           334 non-null    object
#  9   ER status           334 non-null    object
#  10  PR status           334 non-null    object
#  11  HER2 status         334 non-null    object
#  12  Surgery_type        334 non-null    object
#  13  Date_of_Surgery     334 non-null    object
#  14  Date_of_Last_Visit  317 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# Patient_ID             7
# Age                    7
# Gender                 7
# Protein1               7
# Protein2               7
# Protein3               7
# Protein4               7
# Tumour_Stage           7
# Histology              7
# ER status              7
# PR status              7
# HER2 status            7
# Surgery_type           7
# Date_of_Surgery        7
# Date_of_Last_Visit    24
# Patient_Status        20
# dtype: int64

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 7    TCGA-A7-A426  50.0  FEMALE  0.672490   1.27900 -0.321070 -0.112390
# 22   TCGA-AN-A0FY  55.0  FEMALE  0.330640   0.84757 -0.494660  0.116560
# 99   TCGA-A8-A06O  60.0  FEMALE  0.532420   1.54110 -1.009500 -0.125880
# 111  TCGA-MS-A51U  44.0  FEMALE -0.278840   2.16880 -0.462330  0.272200
# 170  TCGA-AR-A0U2  47.0  FEMALE  0.515580   2.65020 -0.103130 -0.045725
# 182  TCGA-C8-A1HI  40.0  FEMALE -1.455300  -0.74177  1.133600 -0.839700
# 189  TCGA-AO-A03O  69.0  FEMALE -0.757790  -0.33780  0.561410  0.208300
# 196  TCGA-C8-A12U  46.0  FEMALE -0.010999   0.86749  0.281570 -0.545880
# 206  TCGA-E9-A1NH  71.0  FEMALE  0.394090   1.70540  0.035642  1.441000
# 219  TCGA-C8-A12X  62.0  FEMALE  0.649340   1.81680  0.279260  0.132280
# 221  TCGA-C8-A12O  50.0  FEMALE -0.322890   0.98848 -0.293130 -0.261700
# 265  TCGA-BH-A18S  79.0  FEMALE  0.978250   1.71050 -0.656300  0.269100
# ...

# %%
data=data.loc[:333] 
data
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# 331  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# 332  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# 333  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
#
#     Tumour_Stage                       Histology ER status PR status  \
# ...

# %%
data.isna().sum()
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Protein1               0
# Protein2               0
# Protein3               0
# Protein4               0
# Tumour_Stage           0
# Histology              0
# ER status              0
# PR status              0
# HER2 status            0
# Surgery_type           0
# Date_of_Surgery        0
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
data.dropna(inplace = True)
data
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# ...

# %%
data.isna().sum()
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Protein1              0
# Protein2              0
# Protein3              0
# Protein4              0
# Tumour_Stage          0
# Histology             0
# ER status             0
# PR status             0
# HER2 status           0
# Surgery_type          0
# Date_of_Surgery       0
# Date_of_Last_Visit    0
# Patient_Status        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 333
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          317 non-null    object
#  1   Age                 317 non-null    float64
#  2   Gender              317 non-null    object
#  3   Protein1            317 non-null    float64
#  4   Protein2            317 non-null    float64
#  5   Protein3            317 non-null    float64
#  6   Protein4            317 non-null    float64
#  7   Tumour_Stage        317 non-null    object
#  8   Histology           317 non-null    object
#  9   ER status           317 non-null    object
#  10  PR status           317 non-null    object
#  11  HER2 status         317 non-null    object
#  12  Surgery_type        317 non-null    object
#  13  Date_of_Surgery     317 non-null    object
#  14  Date_of_Last_Visit  317 non-null    object
# ...

# %%
data.drop(columns = [ "Date_of_Surgery","Date_of_Last_Visit" ], inplace = True)
data
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# ...

# %%
sns.countplot(x="Surgery_type", data=data, hue="Gender")
plt.xticks(rotation =90)
plt.show()

# %%
sns.countplot('Patient_Status',data=data)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.hist(bins =10,figsize=(10,10))
plt.show()

# %%
import numpy as np
x = list(range(20,105,5))
plt.figure(figsize=(8,5))
plt.hist(data['Age'].astype(int),width=4, align='mid', bins = x, color='black')
plt.xticks(x)
plt.xlabel('Ages')
plt.title('Age range')
plt.yticks(np.arange(0,65,5))
plt.show()

# %%
table=pd.crosstab(data['Patient_Status'],data['Surgery_type'])
table
# Out:
# Surgery_type     0   1   2   3
# Patient_Status
# 0               57  72  73  53
# 1                9  17  24  12

# %%
from sklearn import preprocessing
Variable = preprocessing.LabelEncoder()
data['Gender'] = Variable.fit_transform(data['Gender'])
data['ER status'] = Variable.fit_transform(data['ER status'])
data['PR status'] = Variable.fit_transform(data['PR status'])
data['HER2 status'] = Variable.fit_transform(data['HER2 status'])
data['Surgery_type'] = Variable.fit_transform(data['Surgery_type'])
data['Tumour_Stage'] = Variable.fit_transform(data['Tumour_Stage'])
data['Histology'] = Variable.fit_transform(data['Histology'])
data['Patient_Status'] = Variable.fit_transform(data['Patient_Status'])
# Out:
# <ipython-input-95-696addc5ecac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender'] = Variable.fit_transform(data['Gender'])
# <ipython-input-95-696addc5ecac>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ER status'] = Variable.fit_transform(data['ER status'])
# <ipython-input-95-696addc5ecac>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0       0  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0       0 -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0       0  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0       0  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0       0  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0       0  0.231800   0.61804  -0.55779 -0.517350
# 330  TCGA-A8-A085  44.0       1  0.732720   1.11170  -0.26952 -0.354920
# 331  TCGA-A1-A0SG  61.0       0 -0.719470   2.54850  -0.15024  0.339680
# 332  TCGA-A2-A0EU  79.0       0  0.479400   2.05590  -0.53136 -0.188480
# 333  TCGA-B6-A40B  76.0       0 -0.244270   0.92556  -0.41823 -0.067848
#
#      Tumour_Stage  Histology  ER status  PR status  HER2 status  Surgery_type  \
# ...

# %%
data.describe()
# Out:
#               Age      Gender    Protein1    Protein2    Protein3    Protein4  \
# count  317.000000  317.000000  317.000000  317.000000  317.000000  317.000000
# mean    58.725552    0.012618   -0.027232    0.949557   -0.095104    0.006713
# std     12.827374    0.111797    0.543858    0.906153    0.589027    0.625965
# min     29.000000    0.000000   -2.144600   -0.978730   -1.627400   -2.025500
# 25%     49.000000    0.000000   -0.350600    0.368840   -0.531360   -0.382240
# 50%     58.000000    0.000000    0.005649    0.997130   -0.193040    0.038522
# 75%     67.000000    0.000000    0.336260    1.612000    0.251210    0.436250
# max     90.000000    1.000000    1.593600    3.402200    2.193400    1.629900
#
#        Tumour_Stage   Histology  ER status  PR status  HER2 status  \
# count    317.000000  317.000000      317.0      317.0   317.000000
# mean       1.053628    0.331230        0.0        0.0     0.091483
# ...

# %%
x=data[["Age","Gender","Protein1","Protein2","Protein3","Protein4","Tumour_Stage","Histology","ER status","PR status","HER2 status","Surgery_type"]]
#independent variable
y=data["Patient_Status"] #dependent Variable
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(x,y, test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predicted=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predicted)
# Out:
# 0.828125
